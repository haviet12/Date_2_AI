# %% [markdown]
# <a href="https://colab.research.google.com/github/haviet12/Date_2_AI/blob/main/Date_2_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('text.txt', mode ='w') as accounts :
  accounts.write('20146489    Nguyen Viet Ha  8.0\n')
  accounts.write('20146486    Nguyen Viet B  8.0\n')
  accounts.write('20146488    Nguyen Viet C  8.0\n')
  accounts.write('20146452    Nguyen Viet D  8.0\n')
  accounts.write('20146451    Nguyen Viet E  8.0\n')
  accounts.write('20146412    Nguyen Viet F  8.0\n')
  accounts.write('20146483    Nguyen Viet G  8.0\n')
  accounts.write('20146423    Nguyen Viet H  8.0\n')
  accounts.write('20146478    Nguyen Viet I  8.0\n')
  accounts.write('20146479    Nguyen Viet K  8.0\n')
  accounts.write('20146485    Nguyen Viet L  8.0\n')
  accounts.write('20146456    Nguyen Viet M  8.0\n')
  accounts.write('20146445    Nguyen Viet N  8.0\n')
  accounts.write('20146443    Nguyen Viet P  8.0\n')
  accounts.write('20146472    Nguyen Viet Q  8.0\n')
  accounts.write('20146470    Nguyen Viet W  8.0\n')
  accounts.write('20146490    Nguyen Viet R  8.0\n')
  accounts.write('20146460    Nguyen Viet S  8.0\n')
  accounts.write('20146450    Nguyen Viet Y  8.0\n')
  accounts.write('20146440    Nguyen Viet O  8.0\n')
  accounts.write('20146466    Nguyen Viet Z  8.0\n')

# %%
with open('text_1.txt', mode ='w') as data:
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146486    Nguyen Viet B  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)
  print('20146489    Nguyen Viet Ha  8.0\n', file = data)

# %%
import pandas as pd
url = 'data.csv'
dataframe = pd.read_csv(url)
# dataframe.shape ## hiển thị số hàng và số cột 
# dataframe.describe
dataframe.head(20)
dataframe.iloc[:4]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-37143547723e> in <module>
#       1 import pandas as pd
#       2 url = 'data.csv'
# ----> 3 dataframe = pd.read_csv(url)
#       4 # dataframe.shape ## hiển thị số hàng và số cột
#       5 # dataframe.describe
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
## lọc dữ liệu 
import pandas as pd
url = 'data.csv'
dataframe = pd.read_csv(url)
frame = dataframe.set_index(dataframe['Ho va Ten'])
frame.loc['Nguyen Van Trung']
# Out:
# MSSV                 18567852
# Ho va Ten    Nguyen Van Trung
# Khoa                      K18
# Diem                        8
# Name: Nguyen Van Trung, dtype: object

# %%
## lọc dữ liệu 
import pandas as pd
url = 'data.csv'
dataframe = pd.read_csv(url)
dataframe[dataframe['Diem']==8].head(10)
# frame.loc['Nguyen Van Trung']
# Out:
#         MSSV         Ho va Ten Khoa  Diem
# 0   20146489    Nguyen Viet Ha  K20     8
# 5   20146541      Nguyen Van E  K20     8
# 6   20146552      Nguyen Van F  K20     8
# 10  18567852  Nguyen Van Trung  K18     8
# 16  19648535   Nguyen Van Minh  K19     8

# %%
## lọc dữ liệu điểm và khóa
import pandas as pd
url = 'data.csv'
dataframe = pd.read_csv(url)
dataframe[(dataframe['Diem']==8) & (dataframe['Khoa']=='K19')].head(10)
# Out:
#         MSSV        Ho va Ten Khoa  Diem
# 16  19648535  Nguyen Van Minh  K19     8

# %%
## lọc dữ liệu trên 5
import pandas as pd
url = 'data.csv'
dataframe = pd.read_csv(url)
dataframe[(dataframe['Diem']>5)]
# Out:
#         MSSV         Ho va Ten Khoa  Diem
# 0   20146489    Nguyen Viet Ha  K20     8
# 1   20146523      Nguyen Van A  K20     9
# 2   20146950      Nguyen Van B  K20     7
# 4   20146789      Nguyen Van D  K20     6
# 5   20146541      Nguyen Van E  K20     8
# 6   20146552      Nguyen Van F  K20     8
# 7   20146323      Nguyen Van G  K20     9
# 8   17195623      Nguyen Van H  K17     7
# 9   18925023      Nguyen Van I  K18     9
# 10  18567852  Nguyen Van Trung  K18     8
# 11  19562489  Nguyen Van Hoang  K19     6
# 12  19648532   Nguyen Van Dung  K19     7
# 14  19648533    Nguyen Van Tri  K19     9
# 16  19648535   Nguyen Van Minh  K19     8
# 17  19648536      Nguyen Van K  K19     9
# 18  19648537      Nguyen Van L  K19     7

# %%
## lọc dữ liệu 
import pandas as pd
url = 'data.csv'
dataframe = pd.read_csv(url)
dataframe['Khoa'].max()
dataframe['Khoa'].unique()# liệt kê các khoa hiện có 
dataframe['Khoa'].value_counts() # đếm số lượng trong từng khoa
dataframe['Diem'].mean() # tính trung bình
dataframe['Diem'].count() # đếm số phần tử
# Out:
# 19

# %%
## delete columns
import pandas as pd
url = 'data.csv'
dataframe = pd.read_csv(url)
#dataframe.drop(['Khoa'], axis=1).head(20)## xóa 1 cột bất kì
dataframe.drop(dataframe.columns[:2], axis=1)
# Out:
#    Khoa  Diem
# 0   K20     8
# 1   K20     9
# 2   K20     7
# 3   K20     5
# 4   K20     6
# 5   K20     8
# 6   K20     8
# 7   K20     9
# 8   K17     7
# 9   K18     9
# 10  K18     8
# 11  K19     6
# 12  K19     7
# 13  K19     5
# 14  K19     9
# 15  K19     5
# 16  K19     8
# 17  K19     9
# 18  K19     7

# %%
#delete row
import pandas as pd
url = 'data.csv'
dataframe = pd.read_csv(url)
dataframe[dataframe['Khoa']!='K19'] # khi chưa biết index
dataframe[dataframe.index!=4] # khi biết index
# Out:
#         MSSV         Ho va Ten Khoa  Diem
# 0   20146489    Nguyen Viet Ha  K20     8
# 1   20146523      Nguyen Van A  K20     9
# 2   20146950      Nguyen Van B  K20     7
# 3   20146532      Nguyen Van C  K20     5
# 5   20146541      Nguyen Van E  K20     8
# 6   20146552      Nguyen Van F  K20     8
# 7   20146323      Nguyen Van G  K20     9
# 8   17195623      Nguyen Van H  K17     7
# 9   18925023      Nguyen Van I  K18     9
# 10  18567852  Nguyen Van Trung  K18     8
# 11  19562489  Nguyen Van Hoang  K19     6
# 12  19648532   Nguyen Van Dung  K19     7
# 13  19648531   Nguyen Van Kien  K19     5
# 14  19648533    Nguyen Van Tri  K19     9
# 15  19648534    Nguyen Van Tai  K19     5
# 16  19648535   Nguyen Van Minh  K19     8
# 17  19648536      Nguyen Van K  K19     9
# 18  19648537      Nguyen Van L  K19     7

# %%
# gộp nhóm 
import pandas as pd
url = 'data.csv'
dataframe = pd.read_csv(url)
dataframe.groupby('Khoa').count()
# Out:
#       MSSV  Ho va Ten  Diem
# Khoa
# K17      1          1     1
# K18      2          2     2
# K19      8          8     8
# K20      8          8     8

# %%
import pandas as pd
import numpy as np

time = pd.date_range('01/01/2023', periods =100000, freq ='30s')
dataframe =pd.DataFrame(index= time)
dataframe['Acess_Amount']= np.random.randint(1,10,100000)
dataframe.resample('W').sum()
# Out:
#             Acess_Amount
# 2023-01-01         14297
# 2023-01-08        100602
# 2023-01-15        100876
# 2023-01-22        100321
# 2023-01-29        101032
# 2023-02-05         82463

# %%
import pandas as pd
url= 'http://winterolympicsmedals.com/medals.csv'
data=pd.read_csv(url)
print(data)
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
data_del=data.drop(['City','Sport','Event gender','Event'], axis =1)
data_del.groupby('Medal').count()
## tổng hợp số huy chương vàng, bạc, đồng từ năm 1924-> 2006
# Out:
#         Year  Discipline  NOC
# Medal
# Bronze   764         764  764
# Gold     774         774  774
# Silver   773         773  773

# %%
## danh sách giải thưởng của CANADA qua các năm
frame = data.set_index(data['NOC'])
frame.loc['CAN']
# Out:
#      Year         City       Sport       Discipline  NOC            Event  \
# NOC
# CAN  1924     Chamonix  Ice Hockey       Ice Hockey  CAN       ice hockey
# CAN  1928   St. Moritz  Ice Hockey       Ice Hockey  CAN       ice hockey
# CAN  1932  Lake Placid  Ice Hockey       Ice Hockey  CAN       ice hockey
# CAN  1932  Lake Placid     Skating   Figure skating  CAN       individual
# CAN  1932  Lake Placid     Skating    Speed skating  CAN           10000m
# ..    ...          ...         ...              ...  ...              ...
# CAN  2006        Turin     Skating    Speed skating  CAN     Team pursuit
# CAN  2006        Turin      Skiing  Cross Country S  CAN     Sprint 1.5km
# CAN  2006        Turin      Skiing  Cross Country S  CAN      Team sprint
# CAN  2006        Turin      Skiing   Freestyle Ski.  CAN           moguls
# CAN  2006        Turin      Skiing        Snowboard  CAN  Snowboard Cross
#
#     Event gender   Medal
# NOC
# CAN            M    Gold
# ...

# %%
frame = data.set_index(data['NOC'])
filter=frame.loc['CAN']
filter.groupby('Medal').count()
## liệt kê tổng số huy chương mà CANADA đạt được
# Out:
#         Year  City  Sport  Discipline  NOC  Event  Event gender
# Medal
# Bronze    43    43     43          43   43     43            43
# Gold      38    38     38          38   38     38            38
# Silver    38    38     38          38   38     38            38

# %%
## danh sách liệt kê số huy chương đạt được ở từng hạng mục thi đấu olympic 
filter.groupby(['Year','Sport','Event','Medal']).count()
# Out:
#                                         City  Discipline  NOC  Event gender
# Year Sport      Event           Medal
# 1924 Ice Hockey ice hockey      Gold       1           1    1             1
# 1928 Ice Hockey ice hockey      Gold       1           1    1             1
# 1932 Ice Hockey ice hockey      Gold       1           1    1             1
#      Skating    10000m          Bronze     1           1    1             1
#                 1500m           Bronze     1           1    1             1
# ...                                      ...         ...  ...           ...
# 2006 Skating    individual      Bronze     1           1    1             1
#      Skiing     Snowboard Cross Bronze     1           1    1             1
#                 Sprint 1.5km    Gold       1           1    1             1
#                 Team sprint     Silver     1           1    1             1
#                 moguls          Gold       1           1    1             1
#
# ...

# %% [markdown]
# # New Section

# %%
# with open('text.txt', mode ='r') as lists:
#   print(f'{"MSSV":<10}{"Name":<20}{"Score":>4}')
#   for record in lists:
#     mssv, name, score = record.split()
#     print(f'{mssv:<10}{name:<20}{score:>4}')

# %% [markdown]
# # New Section
